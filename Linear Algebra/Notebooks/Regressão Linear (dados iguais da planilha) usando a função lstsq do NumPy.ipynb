# %%
"""
BROWNLEE, Jason. Basics of Linear Algebra for Machine Learning: Discover
the Mathematical Language of Data in Python. 2ª ed. 
MachineLearningMastery.com: 2021.

página: 168, 169
Example of calculating a linear regression solution using an SVD

Adaptado
"""

# least squares via convenience function
from numpy import array
from numpy.linalg import lstsq
from matplotlib import pyplot
# define dataset
data = array([
[1, 6],
[2, 5],
[3, 7],
[4, 10]])
# split into inputs and outputs
X, y = data[:,0], data[:,1]
X = X.reshape((len(X), 1))
# calculate coefficients
m, residuals, rank, s = lstsq(X, y, rcond=None)
print(X)
print(y)
print(m)
print(residuals)
# predict using coefficients
yhat = X.dot(m)
# plot data and predictions
pyplot.scatter(X, y)
pyplot.plot(X, yhat, color='red')
pyplot.show()
# Out:
# [[1]
#  [2]
#  [3]
#  [4]]
# [ 6  5  7 10]
# [2.56666667]
# [12.36666667]

# %%
"""
Algortimo obtido no livro:
BROWNLEE, Jason. Basics of Linear Algebra for Machine Learning: Discover
the Mathematical Language of Data in Python. 2ª ed. 
MachineLearningMastery.com: 2021.

página: 168, 169
Example of calculating a linear regression solution using an SVD

Exercício obtido no livro:
FRANCO, Neide Maria Bertoldi. Cálculo Numérico. 1ª ed. São Paulo: Pearson 
Prentice Hall, 2006.

página 277
"""

# least squares via convenience function
from numpy import array
from numpy.linalg import lstsq
from matplotlib import pyplot
# define dataset
# ano, Número de acidentes (em milhares)
data = array([
[1980, 8300],
[1985, 9900],
[1990, 10400],
[1993, 13200],
[1997, 13600],
[2000, 13700],
[2006, 14600]])
# split into inputs and outputs
X, y = data[:,0], data[:,1]
X = X.reshape((len(X), 1))
# calculate coefficients
b, residuals, rank, s = lstsq(X, y, rcond=None)
print(b)
# predict using coefficients
yhat = X.dot(b)
# plot data and predictions
pyplot.scatter(X, y)
pyplot.plot(X, yhat, color='red')
pyplot.show()
# Out:
# [6.00384775]

# %%
"""
Algortimo obtido no livro:
BROWNLEE, Jason. Basics of Linear Algebra for Machine Learning: Discover
the Mathematical Language of Data in Python. 2ª ed. 
MachineLearningMastery.com: 2021.

página: 168, 169
Example of calculating a linear regression solution using an SVD

Exercício obtido no livro:
FRANCO, Neide Maria Bertoldi. Cálculo Numérico. 1ª ed. São Paulo: Pearson 
Prentice Hall, 2006.

página 277
"""

# least squares via convenience function
from numpy import array
from numpy.linalg import lstsq
from matplotlib import pyplot
# define dataset
# ano, Acidentes por 10000 veículos
data = array([
[1980, 1688],
[1985, 1577],
[1990, 1397],
[1993, 1439],
[1997, 1418],
[2000, 1385],
[2006, 1415]])
# split into inputs and outputs
X, y = data[:,0], data[:,1]
X = X.reshape((len(X), 1))
# calculate coefficients
b, residuals, rank, s = lstsq(X, y, rcond=None)
print(b)
# predict using coefficients
yhat = X.dot(b)
# plot data and predictions
pyplot.scatter(X, y)
pyplot.plot(X, yhat, color='red')
pyplot.show()
# Out:
# [0.73946815]
